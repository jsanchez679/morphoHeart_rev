# %% [markdown]
# Connected to mHpy39_qt (Python 3.9.16)

# %%
mH_settings =  {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 
'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': WindowsPath('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': WindowsPath('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': WindowsPath('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': WindowsPath('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'names': {}, 'cut_info': {'Disc No.0': {'radius': 60, 'normal_unit': [-8.646218929887459, 1.3505552269947216, -4.839307677270893], 'pl_centre': [97.92674746422252, -83.3525009561251, 96.6717029945406], 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 239646.87518697616, 'Cut1_ch1_tiss_segm2': 233777.4398440119, 'Cut1_ch1_ext_segm1': 1132707.885333426, 'Cut1_ch1_ext_segm2': 666060.1459218762}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1 in <cell line: 1>()
# ...

# %%
from pathlib import Path

mH_settings =  {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 
'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': Path('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': Path('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'names': {}, 'cut_info': {'Disc No.0': {'radius': 60, 'normal_unit': [-8.646218929887459, 1.3505552269947216, -4.839307677270893], 'pl_centre': [97.92674746422252, -83.3525009561251, 96.6717029945406], 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 239646.87518697616, 'Cut1_ch1_tiss_segm2': 233777.4398440119, 'Cut1_ch1_ext_segm1': 1132707.885333426, 'Cut1_ch1_ext_segm2': 666060.1459218762}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}

# %%
mH_settings
# Out:
# {'setup': {'no_chs': 2,
#   'name_chs': {'ch1': 'myocardium',
#    'ch2': 'endocardium',
#    'chNS': 'cardiac jelly'},
#   'chs_relation': {'ch1': 'external', 'ch2': 'internal'},
#   'color_chs': {'ch1': {'int': 'gold',
#     'tiss': 'lightseagreen',
#     'ext': 'crimson'},
#    'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}},
#   'orientation': {'stack': 'anterior, ventral, left',
#    'roi': 'anterior, ventral, left'},
#   'rotateZ_90': True,
#   'mask_ch': {'ch1': True, 'ch2': True},
#   'all_contained': True,
#   'one_contained': False,
#   'chNS': {'layer_btw_chs': True,
#    'ch_ext': ('ch1', 'int'),
#    'ch_int': ('ch2', 'ext'),
#    'operation': 'XOR',
#    'user_nsChName': 'cardiac jelly',
#    'color_chns': {'int': 'greenyellow',
#     'tiss': 'darkorange',
#     'ext': 'powderblue'},
#    'keep_largest': {'tiss': False, 'int': True, 'ext': True},
#    'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05},
#    'plot_settings': [False, None]},
# ...

# %%
mH_settings['wf_info']['segments']['setup']
# Out:
# {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#     'tiss': 'cut_with_other_ext-ext'},
#    'chNS': {'tiss': 'cut_with_other_ext-ext'},
#    'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#   'measure': {'ch2': {'int': {}, 'tiss': {}},
#    'chNS': {'tiss': {}},
#    'ch1': {'tiss': {}, 'ext': {}}},
#   'dirs': {'ch2': {'int': {}, 'tiss': {}},
#    'chNS': {'tiss': {}},
#    'ch1': {'tiss': {}, 'ext': {}}},
#   'names': {},
#   'cut_info': {'Disc No.0': {'radius': 60,
#     'normal_unit': [-8.646218929887459,
#      1.3505552269947216,
#      -4.839307677270893],
#     'pl_centre': [97.92674746422252, -83.3525009561251, 96.6717029945406],
#     'height': 0.45,
#     'color': 'purple',
#     'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']['dirs']
# Out:
# {'ch2': {'int': {}, 'tiss': {}},
#  'chNS': {'tiss': {}},
#  'ch1': {'tiss': {}, 'ext': {}}}

# %%
mH_settings
# Out:
# {'setup': {'no_chs': 2,
#   'name_chs': {'ch1': 'myocardium',
#    'ch2': 'endocardium',
#    'chNS': 'cardiac jelly'},
#   'chs_relation': {'ch1': 'external', 'ch2': 'internal'},
#   'color_chs': {'ch1': {'int': 'gold',
#     'tiss': 'lightseagreen',
#     'ext': 'crimson'},
#    'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}},
#   'orientation': {'stack': 'anterior, ventral, left',
#    'roi': 'anterior, ventral, left'},
#   'rotateZ_90': True,
#   'mask_ch': {'ch1': True, 'ch2': True},
#   'all_contained': True,
#   'one_contained': False,
#   'chNS': {'layer_btw_chs': True,
#    'ch_ext': ('ch1', 'int'),
#    'ch_int': ('ch2', 'ext'),
#    'operation': 'XOR',
#    'user_nsChName': 'cardiac jelly',
#    'color_chns': {'int': 'greenyellow',
#     'tiss': 'darkorange',
#     'ext': 'powderblue'},
#    'keep_largest': {'tiss': False, 'int': True, 'ext': True},
#    'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05},
#    'plot_settings': [False, None]},
# ...

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']
# Out:
# {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#    'tiss': 'cut_with_other_ext-ext'},
#   'chNS': {'tiss': 'cut_with_other_ext-ext'},
#   'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#  'measure': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'dirs': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'names': {},
#  'cut_info': {'Disc No.0': {'radius': 60,
#    'normal_unit': [-8.646218929887459, 1.3505552269947216, -4.839307677270893],
#    'pl_centre': [97.92674746422252, -83.3525009561251, 96.6717029945406],
#    'height': 0.45,
#    'color': 'purple',
#    'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}

# %%
mH_settings['setup']['segm']
# Out:
# {'cutLayersIn2Segments': True,
#  'Cut1': {'no_segments': 2,
#   'obj_segm': 'Disc',
#   'no_cuts_4segments': 1,
#   'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'},
#   'ch_segments': {'ch2': ['int', 'tiss'],
#    'chNS': ['tiss'],
#    'ch1': ['tiss', 'ext']},
#   'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}},
#  'measure': {'Vol': True, 'SA': False, 'Ellip': True}}

# %%
mH_settings = {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': Path('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': Path('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 
'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk', 'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'}, 'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk', 'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}}, 'names': {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'}, 'cut_info': {'Disc No.0': {'radius': 65, 'normal_unit': array([-8.8498097 ,  1.88714965, -4.25670464]), 'pl_centre': array([101.37672782, -77.18052599,  98.6222525 ]), 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 
'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 
'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 234841.43480867363, 'Cut1_ch1_tiss_segm2': 238942.29810337856, 'Cut1_ch1_ext_segm1': 1113579.7096028612, 'Cut1_ch1_ext_segm2': 684142.6772649591}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1 in <cell line: 1>()
# ...

# %%
import numpy as np

mH_settings =  {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 
'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': Path('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': Path('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'names': {}, 'cut_info': {'Disc No.0': {'radius': 60, 'normal_unit': [-8.646218929887459, 1.3505552269947216, -4.839307677270893], 'pl_centre': [97.92674746422252, -83.3525009561251, 96.6717029945406], 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 239646.87518697616, 'Cut1_ch1_tiss_segm2': 233777.4398440119, 'Cut1_ch1_ext_segm1': 1132707.885333426, 'Cut1_ch1_ext_segm2': 666060.1459218762}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}

mH_settings = {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': Path('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': Path('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 
'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk', 'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'}, 'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk', 'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}}, 'names': {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'}, 'cut_info': {'Disc No.0': {'radius': 65, 'normal_unit': np.array([-8.8498097 ,  1.88714965, -4.25670464]), 'pl_centre': np.array([101.37672782, -77.18052599,  98.6222525 ]), 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 
'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 
'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 234841.43480867363, 'Cut1_ch1_tiss_segm2': 238942.29810337856, 'Cut1_ch1_ext_segm1': 1113579.7096028612, 'Cut1_ch1_ext_segm2': 684142.6772649591}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']['dirs']
# Out:
# {'ch2': {'int': {}, 'tiss': {}},
#  'chNS': {'tiss': {}},
#  'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk',
#    'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'},
#   'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk',
#    'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}}

# %%
mH_settings['wf_info']['segments']['setup']
# Out:
# {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#     'tiss': 'cut_with_other_ext-ext'},
#    'chNS': {'tiss': 'cut_with_other_ext-ext'},
#    'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#   'measure': {'ch2': {'int': {}, 'tiss': {}},
#    'chNS': {'tiss': {}},
#    'ch1': {'tiss': {}, 'ext': {}}},
#   'dirs': {'ch2': {'int': {}, 'tiss': {}},
#    'chNS': {'tiss': {}},
#    'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk',
#      'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'},
#     'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk',
#      'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}},
#   'names': {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'},
#   'cut_info': {'Disc No.0': {'radius': 65,
#     'normal_unit': array([-8.8498097 ,  1.88714965, -4.25670464]),
#     'pl_centre': array([101.37672782, -77.18052599,  98.6222525 ]),
#     'height': 0.45,
#     'color': 'purple',
# ...

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']
# Out:
# {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#    'tiss': 'cut_with_other_ext-ext'},
#   'chNS': {'tiss': 'cut_with_other_ext-ext'},
#   'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#  'measure': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'dirs': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk',
#     'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'},
#    'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk',
#     'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}},
#  'names': {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'},
#  'cut_info': {'Disc No.0': {'radius': 65,
#    'normal_unit': array([-8.8498097 ,  1.88714965, -4.25670464]),
#    'pl_centre': array([101.37672782, -77.18052599,  98.6222525 ]),
#    'height': 0.45,
#    'color': 'purple',
#    'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}

# %%
mH_settings2 = {'setup': {'no_chs': 2, 'name_chs': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'chs_relation': {'ch1': 'external', 'ch2': 'internal'}, 'color_chs': {'ch1': {'int': 'gold', 'tiss': 'lightseagreen', 'ext': 'crimson'}, 'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}}, 'orientation': {'stack': 'anterior, ventral, left', 'roi': 'anterior, ventral, left'}, 'rotateZ_90': True, 'mask_ch': {'ch1': True, 'ch2': True}, 'all_contained': True, 'one_contained': False, 'chNS': {'layer_btw_chs': True, 'ch_ext': ('ch1', 'int'), 'ch_int': ('ch2', 'ext'), 'operation': 'XOR', 'user_nsChName': 'cardiac jelly', 'color_chns': {'int': 'greenyellow', 'tiss': 'darkorange', 'ext': 'powderblue'}, 'keep_largest': {'tiss': False, 'int': True, 'ext': True}, 'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05}, 'plot_settings': [False, None]}, 'segm': {'cutLayersIn2Segments': True, 'Cut1': {'no_segments': 2, 'obj_segm': 'Disc', 'no_cuts_4segments': 1, 'name_segments': {'segm1': 'atrium', 'segm2': 'ventricle'}, 'ch_segments': {'ch2': ['int', 'tiss'], 'chNS': ['tiss'], 'ch1': ['tiss', 'ext']}, 'colors': {'segm1': [247, 113, 137], 'segm2': [85, 85, 255]}}, 'measure': {'Vol': True, 'SA': False, 'Ellip': True}}, 'sect': {'cutLayersIn2Sections': True, 'Cut1': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'left', 'sect2': 'right'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [102, 194, 165], 'sect2': [252, 141, 98]}}, 'Cut2': {'no_sections': 2, 'obj_sect': 'Centreline', 'name_sections': {'sect1': 'dorsal', 'sect2': 'ventral'}, 'ch_sections': {'ch2': ['tiss'], 'chNS': ['tiss'], 'ch1': ['tiss']}, 'colors': {'sect1': [141, 160, 203], 'sect2': [231, 138, 195]}}, 'measure': {'Vol': True, 'SA': False}}, 'chs_all': {'ch1': 'myocardium', 'ch2': 'endocardium', 'chNS': 'cardiac jelly'}, 'params': {'0': {'s': 'SA', 'l': 'Surface Area'}, '1': {'s': 'Vol', 'l': 'Volume'}, '2': {'s': 'CL', 'l': 'Centreline', 'measure': {'looped_length': True, 'linear_length': True}}, '3': {'s': 'th_i2e', 'l': 'Thickness Heatmap (int>ext*)'}, '4': {'s': 'th_e2i', 'l': 'Thickness Heatmap (ext>int*)'}, '5': {'s': 'ball', 'l': 'Centreline>Tissue (Ballooning)', 'measure': {'1': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch1', 'from_cl_type': 'int'}, '2': {'to_mesh': 'ch1', 'to_mesh_type': 'int', 'from_cl': 'ch2', 'from_cl_type': 'ext'}}}, '6': {'s': 'LoopDir', 'l': 'Looping direction', 'description': "Heart's looping direction", 'type': 'categorical', 'categories': ['dextral', 'sinistral', 'dorsoventral']}, '7': {'s': 'AoLen', 'l': 'Aortic length', 'description': 'Length of the Aorta from the BA to the firts aortic arch', 'type': 'continuous', 'categories': []}, '8': {'s': 'TgBright', 'l': 'Tg Brightness', 'description': 'Transgene Brightness', 'type': 'descriptive', 'categories': []}}, 'keep_largest': {'ch1': {'int': True, 'ext': True, 'tiss': False}, 'ch2': {'int': True, 'ext': True, 'tiss': False}}, 'alpha': {'ch1': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}, 'ch2': {'int': 0.05, 'ext': 0.05, 'tiss': 0.05}}}, 'wf_info': {'keep_largest': {'ch1': {'int': True, 'tiss': False, 'ext': True}, 'ch2': {'int': True, 'tiss': False, 'ext': True}}, 'cleanup': {'ch2': {'cont': ['int', 'tiss', 'ext'], 'with_ch': 'ch1', 'with_cont': 'ext', 'inverted': True}, 'plot2d': False}, 'trimming': {'top': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, 3.2237482771550674, 79.1167574863515]}, 'plane_info_image': {'pl_normal': [-0.8702761246486022, 0.07302169909378939, -0.48712144104737065], 'pl_centre': [-3.2237482771550683, 101.33004787352829, 79.11675748635152]}}, 'bottom': {'chs': {'ch1': {'int': True, 'tiss': True, 'ext': True}, 'ch2': {'int': True, 'tiss': True, 'ext': True}}, 'object': 'Plane', 'plane_info_mesh': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -133.57110609078416, 79.94519976524501]}, 'plane_info_image': {'pl_normal': [-0.9571588051700358, 0.24662770975687895, 0.15172934609213334], 'pl_centre': [133.57110609078418, 61.835891695547865, 79.94519976524502]}}}, 'orientation': {'stack': {'axis': 'anterior, ventral, left', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 3, 'pl_normal': [0.0, 1.0, 0.0]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 5, 'pl_normal': [0.0, -0.0, 1.0]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, 0.0]}}, 'stack_cube': {'pos': [104.64465803993451, -92.37037940508134, 107.43018535975003], 'side': 213.0, 'color': [152, 251, 152], 'rotateY': False}}, 'roi': {'axis': 'anterior, ventral, left', 'reorient': True, 'method': 'Centreline', 'centreline': 'myocardium (ch1_int)', 'plane_orient': 'YZ', 'vector_orient': 'Y+', 'planar_views': {'anterior': {'color': [255, 215, 0, 200], 'idcell': 4, 'pl_normal': [-0.0, 0.7900915145874023, -0.6129888892173767]}, 'ventral': {'color': [0, 0, 205, 200], 'idcell': 3, 'pl_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'left': {'color': [255, 0, 0, 200], 'idcell': 1, 'pl_normal': [1.0, 0.0, -0.0]}}, 'roi_cube': {'pos': [107.07140550190196, -92.2124614334767, 108.01506430802878], 'side': 213.0, 'color': [152, 251, 152], 'rotate_x': 52.19406533931177}, 'settings': {'proj_plane': 'YZ', 'ref_vect': 'Y+', 'ref_vectF': [[0, 1, 0], [0, 0, 0]], 'orient_vect': [[0.0, -35.41216278076172, 21.04227638244629], [0.0, -155.70822143554688, 176.0938720703125]], 'angle_deg': 52.19406533931177}}}, 'chNS': {'plot2d': False}, 'centreline': {'SimplifyMesh': {'plane_cuts': {'bottom': {'dir': True, 'pl_dict': {'pl_normal': [0.2466277097568789, 0.9571588051700356, 0.15172934609213332], 'pl_centre': [61.83589169554785, -130.38632744507777, 79.94519976524501]}}, 'top': {'dir': False, 'pl_dict': {'pl_normal': [0.07302169909378937, 0.8702761246486019, -0.48712144104737054], 'pl_centre': [101.33004787352826, -0.9994012692771719, 79.1167574863515]}}}, 'tol': 2.0}, 'vmtk_CL': {'voronoi': False}, 'buildCL': {'nPoints': 300, 'connect_cl': {'ch1_int': 'Option 1-Point in meshesCut4Cl', 'ch2_ext': 'Option 1-Point in meshesCut4Cl'}}, 'dirs': {'ch1': {'int': {'dir_cleanMesh': Path('LS52 F02_ch1_int_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch1_int_cut4clML.stl')}}, 'ch2': {'ext': {'dir_cleanMesh': Path('LS52 F02_ch2_ext_cut4cl.stl'), 'dir_meshLabMesh': Path('LS52 F02_ch2_ext_cut4clML.stl')}}}}, 'segments': {'radius': {'Cut1': 60}, 'use_centreline': True, 'centreline': 'myocardium (ch1_int)', 'setup': {'Cut1': {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext', 'tiss': 'cut_with_other_ext-ext'}, 'chNS': {'tiss': 'cut_with_other_ext-ext'}, 'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}}, 
'measure': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'dirs': {'ch2': {'int': {}, 'tiss': {}}, 'chNS': {'tiss': {}}, 'ch1': {'tiss': {}, 'ext': {}}}, 'names': {}, 'cut_info': {'Disc No.0': {'radius': 65, 'normal_unit': [-8.849809702405874, 1.8871496491797384, -4.256704644769663], 'pl_centre': [101.37672781944276, -77.18052598814869, 98.62225249545048], 'height': 0.45, 'color': 'purple', 'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}}}, 'sections': {'Cut1': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 3, 'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]}, 'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'}, 'Cut2': {'centreline': 'myocardium (ch1_int)', 'nPoints': 300, 'nRes': 601, 'axis_lab': 'Roi', 'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]}, 'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}, 'heatmaps': {'th_i2e[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_i2e[ch2-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'th_i2e[chNS-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': True}, 'th_e2i[ch1-tiss]': {'default': False, 'min_val': 0.0, 'max_val': 20.0, 'colormap': 'turbo', 'd3d2': False}, 'ball[ch1-int(CL.ch1-int)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': True}, 'ball[ch1-int(CL.ch2-ext)]': {'default': False, 'min_val': 0.0, 'max_val': 60.0, 'colormap': 'turbo', 'd3d2': False}}}, 'measure': {'SA': {}, 'Vol': {'ch1_int_whole': True, 'ch1_tiss_whole': True, 'ch1_ext_whole': True, 'ch2_int_whole': True, 'ch2_tiss_whole': True, 'ch2_ext_whole': True, 'chNS_int_whole': True, 
'chNS_tiss_whole': True, 'chNS_ext_whole': True}, 'CL': {'ch1_int_whole': {'looped_length': 278.5729836723767, 'lin_length': 196.40371704101562}, 'ch2_ext_whole': {'looped_length': 283.3270263262093, 'lin_length': 190.81484985351562}}, 'th_i2e': {'ch1_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 20.6689364333242}, 'range_user': {'min_val': 0.0, 'max_val': 
20.0}, 'colormap': 'turbo'}, 'ch2_tiss_whole': {'range_o': {'min_val': 0.0, 'max_val': 25.93153726273506}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}, 'chNS_tiss_whole': {'range_o': {'min_val': -11.15912594809059, 'max_val': 15.60512163114259}, 'range_user': {'min_val': 0.0, 'max_val': 20.0}, 'colormap': 'turbo'}}, 'th_e2i': {'ch1_tiss_whole': True}, 'ball': {'ch1_int_(ch1_int)': True, 'ch1_int_(ch2_ext)': True}, 'LoopDir': {'roi': True}, 'AoLen': {'roi': True}, 'TgBright': {'roi': True}, 'Vol(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': 171587.41563409223, 'Cut1_chNS_tiss_segm2': 65547.06146452879, 'Cut1_ch1_tiss_segm1': 234841.43480867363, 'Cut1_ch1_tiss_segm2': 238942.29810337856, 'Cut1_ch1_ext_segm1': 1113579.7096028612, 'Cut1_ch1_ext_segm2': 684142.6772649591}, 'Ellip(segm)': {'Cut1_ch2_int_segm1': True, 'Cut1_ch2_int_segm2': True, 'Cut1_ch2_tiss_segm1': True, 'Cut1_ch2_tiss_segm2': True, 'Cut1_chNS_tiss_segm1': True, 'Cut1_chNS_tiss_segm2': True, 'Cut1_ch1_tiss_segm1': True, 'Cut1_ch1_tiss_segm2': True, 'Cut1_ch1_ext_segm1': True, 'Cut1_ch1_ext_segm2': True}, 'Vol(sect)': {'Cut1_ch2_tiss_sect1': 228696.62920727738, 'Cut1_ch2_tiss_sect2': 195972.15312096005, 'Cut1_chNS_tiss_sect1': True, 'Cut1_chNS_tiss_sect2': True, 'Cut1_ch1_tiss_sect1': 244132.6523907116, 'Cut1_ch1_tiss_sect2': 232157.19616130897, 'Cut2_ch2_tiss_sect1': True, 'Cut2_ch2_tiss_sect2': True, 'Cut2_chNS_tiss_sect1': True, 'Cut2_chNS_tiss_sect2': True, 'Cut2_ch1_tiss_sect1': 232110.88629832206, 'Cut2_ch1_tiss_sect2': 244163.6629483923}, 'hm3Dto2D': {'ch1_int': True}}}

# %%
mH_settings2
# Out:
# {'setup': {'no_chs': 2,
#   'name_chs': {'ch1': 'myocardium',
#    'ch2': 'endocardium',
#    'chNS': 'cardiac jelly'},
#   'chs_relation': {'ch1': 'external', 'ch2': 'internal'},
#   'color_chs': {'ch1': {'int': 'gold',
#     'tiss': 'lightseagreen',
#     'ext': 'crimson'},
#    'ch2': {'int': 'deepskyblue', 'tiss': 'darkmagenta', 'ext': 'deeppink'}},
#   'orientation': {'stack': 'anterior, ventral, left',
#    'roi': 'anterior, ventral, left'},
#   'rotateZ_90': True,
#   'mask_ch': {'ch1': True, 'ch2': True},
#   'all_contained': True,
#   'one_contained': False,
#   'chNS': {'layer_btw_chs': True,
#    'ch_ext': ('ch1', 'int'),
#    'ch_int': ('ch2', 'ext'),
#    'operation': 'XOR',
#    'user_nsChName': 'cardiac jelly',
#    'color_chns': {'int': 'greenyellow',
#     'tiss': 'darkorange',
#     'ext': 'powderblue'},
#    'keep_largest': {'tiss': False, 'int': True, 'ext': True},
#    'alpha': {'tiss': 0.05, 'int': 0.05, 'ext': 0.05},
#    'plot_settings': [False, None]},
# ...

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']
# Out:
# {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#    'tiss': 'cut_with_other_ext-ext'},
#   'chNS': {'tiss': 'cut_with_other_ext-ext'},
#   'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#  'measure': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'dirs': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {'segm1': 'LS52 F02_Cut1_ch1_tiss_segm1.vtk',
#     'segm2': 'LS52 F02_Cut1_ch1_tiss_segm2.vtk'},
#    'ext': {'segm1': 'LS52 F02_Cut1_ch1_ext_segm1.vtk',
#     'segm2': 'LS52 F02_Cut1_ch1_ext_segm2.vtk'}}},
#  'names': {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'},
#  'cut_info': {'Disc No.0': {'radius': 65,
#    'normal_unit': array([-8.8498097 ,  1.88714965, -4.25670464]),
#    'pl_centre': array([101.37672782, -77.18052599,  98.6222525 ]),
#    'height': 0.45,
#    'color': 'purple',
#    'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}

# %%
mH_settings2['wf_info']['segments']['setup']['Cut1']
# Out:
# {'ch_info': {'ch2': {'int': 'cut_with_other_ext-ext',
#    'tiss': 'cut_with_other_ext-ext'},
#   'chNS': {'tiss': 'cut_with_other_ext-ext'},
#   'ch1': {'tiss': 'cut_with_ext-ext', 'ext': 'ext-ext'}},
#  'measure': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'dirs': {'ch2': {'int': {}, 'tiss': {}},
#   'chNS': {'tiss': {}},
#   'ch1': {'tiss': {}, 'ext': {}}},
#  'names': {},
#  'cut_info': {'Disc No.0': {'radius': 65,
#    'normal_unit': [-8.849809702405874, 1.8871496491797384, -4.256704644769663],
#    'pl_centre': [101.37672781944276, -77.18052598814869, 98.62225249545048],
#    'height': 0.45,
#    'color': 'purple',
#    'res': [0.22832596445005057, 0.22832596445005057, 0.75]}}}

# %%
mH_settings2['wf_info']['segments']['setup']['Cut1'].keys()
# Out:
# dict_keys(['ch_info', 'measure', 'dirs', 'names', 'cut_info'])

# %%
mH_settings2['wf_info']['segments']['setup']['Cut1']['names']
# Out:
# {}

# %%
mH_settings['wf_info']['segments']['setup']['Cut1']['names']
# Out:
# {'segm1': 'Cut1_ch1_ext_segm1', 'segm2': 'Cut1_ch1_ext_segm2'}

# %%
mH_settings['wf_info']['sections']
# Out:
# {'Cut1': {'centreline': 'myocardium (ch1_int)',
#   'nPoints': 300,
#   'nRes': 601,
#   'axis_lab': 'Roi',
#   'direction': {'plane_no': 3,
#    'plane_normal': [-0.0, 0.6129888892173767, 0.7900915741920471]},
#   'mask_name': 'LS52 F02_mask_Cut1_sect1.npy'},
#  'Cut2': {'centreline': 'myocardium (ch1_int)',
#   'nPoints': 300,
#   'nRes': 601,
#   'axis_lab': 'Roi',
#   'direction': {'plane_no': 1, 'plane_normal': [1.0, 0.0, -0.0]},
#   'mask_name': 'LS52 F02_mask_Cut2_sect1.npy'}}
